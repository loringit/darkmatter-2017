# %% [markdown]
# # Импорт библиотек

# %%
import pandas as pd
import glob
import numpy as np
from sklearn.neighbors import BallTree, KDTree, DistanceMetric
from catboost import CatBoostRegressor, Pool, cv
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import matplotlib.lines as lines
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import subprocess
from tqdm import tqdm

# %% [markdown]
# # Обзор данных

# %% [markdown]
# ## Прочитаем тестовые данные

# %%
test = pd.concat([pd.read_hdf(file) for file in ['data/test_close0.h5', 'data/test_close10.h5']])
test.head()
# Out:
#          TX        TY             X             Y        Z  data_ind
# 0  0.087240  0.119438  86536.218750  62988.312500  56892.0         0
# 1 -0.380208  0.198382  93346.765625  58062.937500  14223.0         0
# 2 -0.348549 -0.099981  66129.578125  23038.673828  46548.0         0
# 3  0.585342 -0.126879  68825.523438  55186.625000  45255.0         0
# 4  0.038579 -0.131510  36366.941406  47564.878906   9051.0         0

# %% [markdown]
# # Попробуем теперь визуализировать данные

# %%
df_open30 = pd.read_hdf('data/dm4/open30.h5')
first = df_open30[df_open30.data_ind == df_open30.data_ind[0]]

for index in first.event_id.unique()[1:]:
    ev = first[first.event_id == index]
    ax = plt.gca(projection='3d')
    ax.scatter3D(ev.X, ev.Y, ev.Z)

# %% [markdown]
# ## Видно, что в одной группе несколько ливней. Давайте попробуем взглянуть как распределены шум и сигнал вдоль осей.

# %%
def make_plot(axis):
    figure = plt.figure(figsize = [20, 10])
    figure.suptitle('Распредление шума и сигнала вдоль ' + axis, fontsize=20)
    
    figure.add_subplot(221)
    plt.title('Сигнал')
    plt.hist(first.loc[first.signal == 1, axis], bins=1000, histtype='step', color = 'green')
    
    figure.add_subplot(222)
    plt.title('Шум')
    plt.hist(first.loc[first.signal == 0, axis], bins=1000, histtype='step', color = 'red')
    
    figure.add_subplot(223)
    plt.title('Все значения')
    values_X = plt.hist(first.loc[:, axis], bins=1000, histtype='step', color = 'blue')
    
    plt.show()

# %%
for axis in ['X', 'Y', 'Z']:
    make_plot(axis)

# %% [markdown]
# ## Можно заметить, что слайсы по Z практически на одинаковом расстоянии. Посмотрим, что это за расстояние.

# %%
z_values = np.array(sorted(np.unique(first.Z)))
between_z = []

for i in range(1, len(z_values)):
    between_z.append(int(z_values[i] - z_values[i - 1]))
    
unique, counts = np.unique(between_z, return_counts = True)
print(np.asarray((unique, counts)).T)
# Out:
# [[   3    2]
#  [   4    1]
#  [   5    1]
#  [  14    1]
#  [  37    1]
#  [  41    1]
#  [  77    1]
#  [  83    1]
#  [ 174    1]
#  [ 196    1]
#  [ 224    1]
#  [ 275    1]
#  [1013    1]
#  [1068    1]
#  [1096    1]
#  [1118    1]
#  [1209    1]
#  [1215    1]
#  [1247    1]
#  [1255    1]
#  [1269    1]
#  [1293   48]]

# %% [markdown]
# ## Получается, что это расстояние 1293

# %% [markdown]
# # Группировка на пары

# %% [markdown]
# ## Ребята рассказали, что необходимо разбить данные на пары с помощью BallTree в пространстве координат и углов.

# %%
columns = ['TX', 'TY', 'X', 'Y', 'Z']
for_metric = columns[:-1]

def add_neighbours(df, k, same_pair, metric='minkowski'):
    result = []
    indexes = []
    for data_ind in tqdm(df.data_ind.unique()):
        ind = df[df.data_ind == data_ind]
        values = list(sorted(ind.Z.unique()))
        for z, z_next in zip(values, values[1:]):
            z, z_next = ind[ind.Z == z].copy(), ind[ind.Z == z_next].copy()
            
            z[['TX', 'TY']] *= 1293
            z_next[['TX', 'TY']] *= 1293
            
            b_tree = BallTree(z_next[for_metric], metric=metric)
            d, idx = b_tree.query(z[for_metric], k=min(k, len(z_next)))
            
            for i in range(idx.shape[1]):
                data = z_next.iloc[idx[:, i]]
                temp = z.copy()
                
                for col in columns:
                    temp[col + '_pair'] = data[col].values
                    
                if same_pair:
                    temp['same_pair'] = data.event_id.values == z.event_id.values
                    
                result.append(temp)
                indexes = np.unique(list(indexes) + list(temp.index.unique()))
            
            b_tree = BallTree(z[for_metric], metric=metric)
            d, idx = b_tree.query(z_next[for_metric], k=min(k, len(z)))
            
            for i in range(idx.shape[1]):
                data = z.iloc[idx[:, i]]
                temp = z_next.copy()
                
                for col in columns:
                    temp[col + '_pair'] = data[col].values
                    
                if same_pair:
                    temp['same_pair'] = data.event_id.values == z_next.event_id.values
                    
                result.append(temp)
                indexes = np.unique(list(indexes) + list(temp.index.unique()))
                
        indexes = np.unique(list(indexes) + list(z_next.index.unique()))
            
    result = pd.concat(result, axis=0)
    
    for col in columns:
        result['d' + col] = result[col].values - result[col + '_pair'].values
    return result

def make_train(df, k):
    t = add_neighbours(df, k=k, same_pair=True)
    noise = t.event_id == -999
    signal, not_signal = t[~noise], t[noise]
    noise_part = not_signal.sample(len(signal))
    return pd.concat([signal, noise_part]).reset_index(drop=True)

# %% [markdown]
# # Обучение

# %%
train = []
for file in glob.glob('data/dm4/open*.h5')[:5]:
    train.append(make_train(pd.read_hdf(file), k=3))
    
train = pd.concat(train)
# Out:
# 100%|██████████| 1/1 [00:21<00:00, 21.41s/it]
# [False False False ... False False False]
# 698798
# 698798
# 100%|██████████| 10/10 [29:33<00:00, 251.10s/it]
# [False False False ... False False False]
# 6994813
# 6994813
# 100%|██████████| 10/10 [28:22<00:00, 244.61s/it]
# [False False False ... False False False]
# 6984095
# 6984095
# 100%|██████████| 10/10 [28:26<00:00, 246.19s/it]
# [False False False ... False False False]
# 7030307
# 7030307
# 100%|██████████| 10/10 [28:04<00:00, 242.05s/it]
# [False False False ... False False False]
# 6984671
# 6984671

# %% [markdown]
# ## Выделяем нужные данные для обучения

# %%
y_train = train.signal
X_train = train.drop(['event_id', 'signal', 'data_ind', 'same_pair'], axis=1)

# %% [markdown]
# ## Создаем и обучаем модель

# %%
pool = Pool(X_train, y_train)
params = {
    'custom_metric': ['AUC:hints=skip_train~false'],
    'random_seed': 42,
    'logging_level': 'Verbose',
    'learning_rate': 0.05,
    'max_depth': 15,
}

cv(
    pool,
    params,
    num_boost_round=20,
    nfold=5
)
# Out:
# 0:	learn: 0.6825336	test: 0.6825406	best: 0.6825406 (0)	total: 37.9s	remaining: 12m
# 1:	learn: 0.6594851	test: 0.6594977	best: 0.6594977 (1)	total: 1m 13s	remaining: 11m 5s
# 2:	learn: 0.6379594	test: 0.6379793	best: 0.6379793 (2)	total: 1m 49s	remaining: 10m 20s
# 3:	learn: 0.6177250	test: 0.6177520	best: 0.6177520 (3)	total: 2m 25s	remaining: 9m 43s
# 4:	learn: 0.5987186	test: 0.5987531	best: 0.5987531 (4)	total: 3m 3s	remaining: 9m 11s
# 5:	learn: 0.5810883	test: 0.5811285	best: 0.5811285 (5)	total: 3m 39s	remaining: 8m 32s
# 6:	learn: 0.5647103	test: 0.5647556	best: 0.5647556 (6)	total: 4m 14s	remaining: 7m 52s
# 7:	learn: 0.5492234	test: 0.5492801	best: 0.5492801 (7)	total: 4m 51s	remaining: 7m 17s
# 8:	learn: 0.5349102	test: 0.5349797	best: 0.5349797 (8)	total: 5m 28s	remaining: 6m 41s
# 9:	learn: 0.5215283	test: 0.5216052	best: 0.5216052 (9)	total: 6m 5s	remaining: 6m 5s
# 10:	learn: 0.5090924	test: 0.5091784	best: 0.5091784 (10)	total: 6m 41s	remaining: 5m 28s
# ...

# %%
model = CatBoostRegressor(
    iterations=100,
    custom_metric=['AUC:hints=skip_train~false'],
    random_seed=42,
    logging_level='Verbose',
    learning_rate=0.05,
    max_depth=15,
)
model.fit(
    pool,
    logging_level='Verbose',
    plot=True
);
# Out:
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
# ...

# %% [markdown]
# # Добавляем соседей к тестовому датасету

# %%
test_with_neighbours = add_neighbours(test, k=10, same_pair=False)
# Out:
# 100%|██████████| 11/11 [1:56:42<00:00, 1199.48s/it]
# [False False False ... False False False]
# 6998081
# 6998081

# %%
X_test = test_with_neighbours.drop(['data_ind'], axis=1).reset_index(drop=True)
X_test.head()
# Out:
#            TX          TY             X             Y    Z     TX_pair  \
# 0 -193.084152  623.975891  37949.000000  24967.570312  0.0 -350.331818
# 1 -225.433212 -367.239899  39335.953125  49094.968750  0.0 -380.564331
# 2 -288.543915  744.821838  51992.125000  74045.695312  0.0 -166.982605
# 3 -131.043716 -389.968414  29508.035156  67410.984375  0.0 -486.173767
# 4 -233.201782  573.095337  67685.781250  75164.359375  0.0  135.409042
#
#       TY_pair        X_pair        Y_pair  Z_pair         dTX         dTY  \
# 0  437.505890  38081.851562  24522.312500  1293.0  157.247665  186.470001
# 1  458.562836  39409.578125  49534.917969  1293.0  155.131119 -825.802734
# 2  638.900269  51851.539062  73873.390625  1293.0 -121.561310  105.921570
# 3  107.317078  29299.156250  67238.296875  1293.0  355.130066 -497.285492
# 4  775.318970  67272.015625  75664.359375  1293.0 -368.610840 -202.223633
#
#            dX          dY      dZ
# 0 -132.851562  445.257812 -1293.0
# ...

# %% [markdown]
# ## В качестве финального предсказания возьмём среднюю вероятность для каждой точки

# %%
pred = model.predict(X_test)

# %%
raw = pd.DataFrame({'id': test_with_neighbours.index, 'prob': pred}).groupby('id')
agg = raw.aggregate(('mean', 'max', 'min'))['prob']

# %%
plt.hist(agg['mean'], bins=100);
agg.shape
# Out:
# (6998081, 3)

# %%
result = pd.DataFrame(data={'id': agg.index, 'signal': agg['mean'].values}) 

result.to_csv('submit.csv', index=False)

# %%
pred.shape
# Out:
# (40098711,)

# %%
example = pd.read_csv('example.csv')

# %%
example.shape
# Out:
# (7698899, 2)

# %%
len(test_with_neighbours.index.unique())
# Out:
# 6998081
